# %%
# critical
import argparse
import os
import random
import time
import math

# machine learning
from sklearn.decomposition import PCA

# deep learning
import torch
import torch.nn as nn
import torch.nn.parallel
import torch.nn.functional as F
import torch.optim as optim
import torch.optim.lr_scheduler as lr_scheduler
from torch.utils.data import Dataset, DataLoader
from torchsummary import summary
import torchvision.utils as vutils

# data
import numpy as np
import pandas as pd

# plotting
import matplotlib.pyplot as plt
import seaborn as sns

# signal processing
from scipy import signal
from scipy.stats import entropy

# %%
# set random seed for reproducibility
manualSeed = 999
#manualSeed = random.randint(1, 10000) # use if you want new results
print("Random Seed: ", manualSeed)

np.random.seed(manualSeed)
torch.manual_seed(manualSeed)
torch.use_deterministic_algorithms(True) # Needed for reproducible results
# Out:
# Random Seed:  999

# %%
device = torch.device("mps")

# %% [markdown]
# ### Select Signals

# %%
gw_df = pd.read_csv('../data/gw-raw-data/richers_1764.csv')
parameters_df = pd.read_csv('../data/gw-raw-data/richers_1764_parameters.csv')
selected_indexes = parameters_df[parameters_df['beta1_IC_b'] > 0].index
gw_df = gw_df.iloc[:, selected_indexes]
signals = gw_df.values

# %% [markdown]
# ### Apply Augmentation Methods

# %%
def reshape_signal(signal):
    reshaped_signals = np.empty(shape=(256, 0)).astype('float32')

    for i in range(signal.shape[1]):
        current_signal = signal[:, i].reshape(-1, 1)
        current_signal = current_signal[-256:]
        reshaped_signals = np.concatenate((reshaped_signals, current_signal), axis=1)

    return reshaped_signals

def shift_augmentation(signal):
    shifted_signals = np.empty(shape=(256, 0)).astype('float32')

    for i in range(signal.shape[1]):
        current_signal = signal[:, i].reshape(-1, 1)

        shift = np.random.normal(0, 25, 1)
        shifted_signal = np.roll(current_signal, int(shift), axis=0)
        shifted_signal = shifted_signal.reshape(-1, 1)

        shifted_signals = np.concatenate((shifted_signals, shifted_signal), axis=1)

    return shifted_signals

def scale_augmentation(signal):
    scaled_signals = np.empty(shape=(256, 0)).astype('float32')

    for i in range(signal.shape[1]):
        current_signal = signal[:, i].reshape(-1, 1)

        scale_factor = np.random.normal(1, 0.5, 1)
        scale_factor = np.maximum(scale_factor, 0)
        scaled_signal = scale_factor * signal

        scaled_signals = np.concatenate((scaled_signals, scaled_signal), axis=1)

    return scaled_signals

def mixture_augmentation(signal):
    mixture_signals = np.empty(shape=(256, 0)).astype('float32')
    other_signals = np.empty(shape=(256, 0)).astype('float32')

    for i in range(signal.shape[1]):
        current_signal = signal[:, i].reshape(-1, 1)

        other_index = np.random.randint(0, signals.shape[1], 1)
        other_signal = signals[:, other_index].reshape(-1, 1)        
        distance_multiplier = np.random.normal(0.5, 0.2, 1)
        # clip signal to range [0,1] as this is the multiplier by the normalised difference in signals
        distance_multiplier = np.clip(distance_multiplier, 0, 1)
        mixture_signal = current_signal + distance_multiplier * (other_signal - current_signal)

        mixture_signals = np.concatenate((mixture_signals, mixture_signal), axis=1)
        other_signals = np.concatenate((other_signals, other_signal), axis=1)

    return mixture_signals, other_signals

def window_warping_augmentation(signal):
    warped_signals = np.empty(shape=(256, 0)).astype('float32')

    for i in range(signal.shape[1]):
        current_signal = signal[:, i].reshape(1, -1)
        # take window size of 10% of the signal with a warping factor of 2 or 0.5 (from literature)
        warping_factor =  np.random.choice([0.5, 2])
        # warping_factor = 0.5

        window_size = math.floor(current_signal.shape[1] / 10)
        scaled_window_size = warping_factor * window_size

        # don't warp anything a little bit before the core-bounce - preserves core-bounce position
        window_min_idx = 53

        # find random reference position for start of window warping
        window_start_idx = np.random.randint(window_min_idx, current_signal.shape[1] - scaled_window_size*2)
        window_end_idx = window_start_idx + window_size

        # select between warping by factor 1/2 or 2
        if (warping_factor == 2):
            # extract values before, at and after the window
            # clip end of signal to make up for extra size due to window warping
            signal_before_window = current_signal[0][:window_start_idx]
            signal_window = current_signal[0][window_start_idx:window_end_idx]
            signal_after_window = current_signal[0][window_end_idx:int(current_signal.shape[1]-(window_size))]

            # time points
            t = np.arange(len(signal_window))
            warped_t = np.arange(0, len(signal_window), 0.5)

            # interpolation for window warping
            signal_window_warped = np.interp(warped_t, t, signal_window)

            # combine signals
            warped_signal = np.concatenate((signal_before_window, signal_window_warped, signal_after_window), axis=0)
        elif (warping_factor == 0.5):
            # extract values before, at and after the window
            # clip end of signal to make up for extra size due to window warping
            signal_before_window = current_signal[0][:window_start_idx]
            signal_window = current_signal[0][window_start_idx:window_end_idx]
            signal_after_window = current_signal[0][window_end_idx:]
            # add values to end of signal to make up for downsampled window
            signal_after_window = np.pad(signal_after_window, (0, int(window_size - scaled_window_size)), mode='edge')

            signal_window_warped = signal_window[::int(1/warping_factor)]

            warped_signal = np.concatenate((signal_before_window, signal_window_warped, signal_after_window), axis=0)
        else:
            warped_signal = current_signal
        
        warped_signals = np.insert(warped_signals, warped_signals.shape[1], warped_signal, axis=1)

    return warped_signals

# %%
signals = reshape_signal(signals)
selected_indexes = [0, 1442, 1614]
selected_signals = signals[:, selected_indexes]

shifted_augmented_signals = shift_augmentation(selected_signals)
scaled_augmented_signals = scale_augmentation(selected_signals)
mixture_augmented_signals, other_signals = mixture_augmentation(selected_signals)
window_warped_augmented_signals = window_warping_augmentation(selected_signals)
# Out:
# /var/folders/qy/p5knypnd54x1dfyxqbs0175r0000gn/T/ipykernel_1164/1983849162.py:18: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   shifted_signal = np.roll(current_signal, int(shift), axis=0)

# %%
ylim_signal = (signals[:,:].min(), signals[:,:].max())

# %%
num_rows = 1
num_cols = 3

# Determine the common limits for all subplots

fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, 4))

axes = axes.flatten()

# plot each signal on a separate subplot
for i, ax in enumerate(axes):
    x = np.arange(len(selected_signals))
    y = selected_signals[:, i]
    ax.plot(x, y, color='blue', linestyle='-')

    ax.axvline(x=53, color='black', linestyle='--', alpha=0.5)
    ax.grid(True)
    ax.set_ylim(ylim_signal)
    
    # Add axis titles
    ax.set_ylabel('distance * strain (cm^2)')
    ax.set_xlabel('n (timestamps)')

for i in range(len(selected_signals), num_rows*num_cols):
    fig.delaxes(axes[i])

plt.tight_layout()
# plt.savefig('../plots/signal-manipulation/gw_signals_cut.png')
plt.show()

# %%
num_rows = 1
num_cols = 3

fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, 4))
axes = axes.flatten()

for i, ax in enumerate(axes):
    x = np.arange(len(selected_signals))

    y_selected = selected_signals[:, i]
    ax.plot(x, y_selected, color='blue', linestyle='--', label='Original Signal', alpha=0.75)

    y_shifted = shifted_augmented_signals[:, i]
    ax.plot(x, y_shifted, color='purple', linestyle='-', label='Time-Shift Augmented Signals')

    ax.axvline(x=53, color='black', linestyle='--', alpha=0.5)
    ax.grid(True)
    ax.set_ylim(ylim_signal)

    ax.set_ylabel('distance * strain (cm^2)')
    ax.set_xlabel('n (timestamps)')

    ax.legend()

for i in range(len(shifted_augmented_signals), num_rows*num_cols):
    fig.delaxes(axes[i])

plt.tight_layout()
plt.savefig('../plots/data-augmentation/gw_signals_time_shift_augmentation_demonstration.png')
plt.show()

# %%
num_rows = 1
num_cols = 3

fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, 4))
axes = axes.flatten()

for i, ax in enumerate(axes):
    x = np.arange(len(selected_signals))

    y_selected = selected_signals[:, i]
    ax.plot(x, y_selected, color='blue', linestyle='--', label='Original Signal', alpha=0.75)

    y_scaled = scaled_augmented_signals[:, i]
    ax.plot(x, y_scaled, color='purple', linestyle='-', label='Scale Augmented Signals')

    ax.axvline(x=53, color='black', linestyle='--', alpha=0.5)
    ax.grid(True)
    ax.set_ylim(ylim_signal)

    ax.set_ylabel('distance * strain (cm^2)')
    ax.set_xlabel('n (timestamps)')

    ax.legend()

for i in range(len(scaled_augmented_signals), num_rows*num_cols):
    fig.delaxes(axes[i])

plt.tight_layout()
plt.savefig('../plots/data-augmentation/gw_signals_scale_augmentation_demonstration.png')
plt.show()

# %%
num_rows = 1
num_cols = 3

fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, 4))
axes = axes.flatten()

for i, ax in enumerate(axes):
    x = np.arange(len(selected_signals))

    y_selected = selected_signals[:, i]
    ax.plot(x, y_selected, color='blue', linestyle='--', label='Original Signal 1', alpha=0.5)

    y_other = other_signals[:, i]
    ax.plot(x, y_other, color='blue', linestyle='--', label='Original Signal 2', alpha=0.5)

    y_mixture = mixture_augmented_signals[:, i]
    ax.plot(x, y_mixture, color='purple', linestyle='-', label='Mixture Augmented Signals')

    ax.axvline(x=53, color='black', linestyle='--', alpha=0.5)
    ax.grid(True)
    ax.set_ylim(ylim_signal)

    ax.set_ylabel('distance * strain (cm^2)')
    ax.set_xlabel('n (timestamps)')

    ax.legend()

for i in range(len(mixture_augmented_signals), num_rows*num_cols):
    fig.delaxes(axes[i])

plt.tight_layout()
plt.savefig('../plots/data-augmentation/gw_signals_mixture_augmentation_demonstration.png')
plt.show()

# %%
num_rows = 1
num_cols = 3

fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, 4))
axes = axes.flatten()

for i, ax in enumerate(axes):
    x = np.arange(len(selected_signals))

    y_selected = selected_signals[:, i]
    ax.plot(x, y_selected, color='blue', linestyle='--', label='Original Signal', alpha=0.75)

    y_warped = window_warped_augmented_signals[:, i]
    ax.plot(x, y_warped, color='purple', linestyle='-', label='Window-Warped Augmented Signals')

    ax.axvline(x=53, color='black', linestyle='--', alpha=0.5)
    ax.grid(True)
    ax.set_ylim(ylim_signal)

    ax.set_ylabel('distance * strain (cm^2)')
    ax.set_xlabel('n (timestamps)')

    ax.legend()

for i in range(len(window_warped_augmented_signals), num_rows*num_cols):
    fig.delaxes(axes[i])

plt.tight_layout()
plt.savefig('../plots/data-augmentation/gw_signals_window_warped_augmentation_demonstration.png')
plt.show()
